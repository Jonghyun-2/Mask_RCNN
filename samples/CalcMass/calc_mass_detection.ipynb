# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.2/matplotlibrc.template
# or from the matplotlib source distribution
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# Downloading pretrained model to D:\Codes\Mask_RCNN\mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
import tensorflow as tf

cf = tf.ConfigProto()
cf.gpu_options.allow_growth = True
sess = tf.Session(config=cf)

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# # Tutorial
# ---

# %% [markdown]
# ## Configurations

# %%
class CalcMassConfig(Config):
    """
    Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 4

    # Number of classes (including background)
    NUM_CLASSES = 1 + 2  # background + 2 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_RESIZE_MODE = "square"
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    IMAGE_CHANNEL_COUNT = 3
    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 200

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 5
    
config = CalcMassConfig()
#config.display()

# %% [markdown]
# ## Notebook Preferences

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
import json
import skimage
class CalcMassDataset(utils.Dataset):

    def load_full_mammo_img(self, dataset_dir, subset):
        """Load a subset of the Balloon dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        
        self.add_class("AbnormalType", 1, "Calc")
        self.add_class("AbnormalType", 2, "Mass")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)
        print("path join : " ,dataset_dir)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "anno01.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "AbnormalType",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a balloon dataset image, delegate to parent class.
        info = self.image_info[image_id]
        shapes = info['id']
        #print(polygons)
        #print(len(polygons))
        #print(polygons[0]["name"])
        
        count = len(info["polygons"])
        #print(shapes)
        #print(count)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        
        for i, p in enumerate(info["polygons"]):
            #print(p)
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_point_y'], p['all_point_x'])
            mask[rr, cc, i] = 1
            
        # Map class names to class IDs.
        #print('shapes',shapes)
        class_ids = np.array([self.class_names.index(info["polygons"][0]["name"])]*count)
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ## Load dataset

# %%
# ROOT_DIR = r'D:\Gproject\DataSet\tcia_data'
# CALCMASS_DIR = os.path.join(ROOT_DIR, "dataset_dir")

# # Load validation dataset
# dataset = CalcMassDataset()
# dataset.load_full_mammo_img(CALCMASS_DIR, "train")

# # Must call before using the dataset
# dataset.prepare()

# print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# Images: 632
# Classes: ['BG', 'Calc', 'Mass']

# %%
ROOT_DIR = r'D:\Gproject\DataSet\tcia_data'
CALCMASS_DIR = os.path.join(ROOT_DIR, "dataset_dir")

# Training dataset
dataset_train = CalcMassDataset()
dataset_train.load_full_mammo_img(CALCMASS_DIR, "train")
dataset_train.prepare()

# Validation dataset
dataset_val = CalcMassDataset()
dataset_val.load_full_mammo_img(CALCMASS_DIR, "val")
dataset_val.prepare()

print("Images: {}\nClasses: {}".format(len(dataset_train.image_ids), dataset_train.class_names))
print("Images: {}\nClasses: {}".format(len(dataset_val.image_ids), dataset_val.class_names))
# Out:
# path join :  D:\Gproject\DataSet\tcia_data\dataset_dir\train
# path join :  D:\Gproject\DataSet\tcia_data\dataset_dir\val
# Images: 2364
# Classes: ['BG', 'Calc', 'Mass']
# Images: 632
# Classes: ['BG', 'Calc', 'Mass']

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)

#4개의 랜덤이미지를 보여줌
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %% [markdown]
# # Create and Training model
# ---

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\tensorflow\python\ops\array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead

# %%
# Which weights to start with?
init_with = "imagenet"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
hist = model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=30, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: D:\Gproject\Codes\Mask_RCNN_1.14\logs\shapes20200519T1033\mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\rcnn_1.14\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/30
# 200/200 [==============================] - 132s 661ms/step - loss: 2.7629 - rpn_class_loss: 0.0702 - rpn_bbox_loss: 1.5729 - mrcnn_class_loss: 0.0319 - mrcnn_bbox_loss: 0.6404 - mrcnn_mask_loss: 0.4475 - val_loss: 1.3319 - val_rpn_class_loss: 0.0417 - val_rpn_bbox_loss: 1.1587 - val_mrcnn_class_loss: 0.0318 - val_mrcnn_bbox_loss: 0.2998 - val_mrcnn_mask_loss: 0.4017
# Epoch 2/30
# 200/200 [==============================] - 120s 602ms/step - loss: 2.6545 - rpn_class_loss: 0.0411 - rpn_bbox_loss: 1.2395 - mrcnn_class_loss: 0.0469 - mrcnn_bbox_loss: 0.7087 - mrcnn_mask_loss: 0.6182 - val_loss: 2.6956 - val_rpn_class_loss: 0.0408 - val_rpn_bbox_loss: 1.3379 - val_mrcnn_class_loss: 0.0667 - val_mrcnn_bbox_loss: 0.7007 - val_mrcnn_mask_loss: 0.6854
- val_rpn_class_loss: 0.0164 - val_rpn_bbox_loss: 0.7847 - val_mrcnn_class_loss: 0.1418 - val_mrcnn_bbox_loss: 0.5230 - val_mrcnn_mask_loss: 0.5305
# Epoch 30/30
# 200/200 [==============================] - 124s 619ms/step - loss: 1.0440 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.2088 - mrcnn_class_loss: 0.1110 - mrcnn_bbox_loss: 0.2400 - mrcnn_mask_loss: 0.4618 - val_loss: 1.6306 - val_rpn_class_loss: 0.0230 - val_rpn_bbox_loss: 0.9607 - val_mrcnn_class_loss: 0.1262 - val_mrcnn_bbox_loss: 0.4219 - val_mrcnn_mask_loss: 0.4644

# %% [markdown]
# # Detection
# ---

# %%
class InferenceConfig(CalcMassConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights from  D:\Gproject\Codes\Mask_RCNN_1.14\logs\shapes20200519T1033\mask_rcnn_shapes_0030.h5
# Re-starting from epoch 30

# %%
# Test on a random image
# well : 529
# 478
image_id = random.choice(dataset_val.image_ids)

print(image_id)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_val.class_names, figsize=(8, 8))


results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# 578
# original_image           shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (15,)                 min:    0.00000  max:  760.00000  float64
# gt_class_id              shape: (1,)                  min:    2.00000  max:    2.00000  int32
# gt_bbox                  shape: (1, 4)                min:   95.00000  max:  142.00000  int32
# gt_mask                  shape: (256, 256, 1)         min:    0.00000  max:    1.00000  bool
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 15)               min:    0.00000  max:  256.00000  int32
# anchors                  shape: (1, 16368, 4)         min:   -0.35494  max:    1.10396  float32

# %%
#bbox
r['rois'][0]

#r['masks'].shape
#순위
#r['scores']
# Out:
# array([ 75, 104, 186, 180])

# %%
r['scores']
# Out:
# array([0.80305284, 0.77944916, 0.76052433, 0.7571661 ], dtype=float32)

# %% [markdown]
# ## Evaluation
# ---

# %% [markdown]
# # Tunning
# ---

# %% [markdown]
# # DataSet_ tunning
# ---

# %%
# import json
# import skimage
# class CalcMassDataset_normalize(utils.Dataset):

#     def load_full_mammo_img(self, dataset_dir, subset):
#         """Load a subset of the Balloon dataset.
#         dataset_dir: Root directory of the dataset.
#         subset: Subset to load: train or val
#         """
        
#         self.add_class("AbnormalType", 1, "Calc")
#         self.add_class("AbnormalType", 2, "Mass")

#         # Train or validation dataset?
#         assert subset in ["train", "val","test"]
#         dataset_dir = os.path.join(dataset_dir, subset)
#         print("path join : " ,dataset_dir)

#         # Load annotations
#         # VGG Image Annotator (up to version 1.6) saves each image in the form:
#         # { 'filename': '28503151_5b5b7ec140_b.jpg',
#         #   'regions': {
#         #       '0': {
#         #           'region_attributes': {},
#         #           'shape_attributes': {
#         #               'all_points_x': [...],
#         #               'all_points_y': [...],
#         #               'name': 'polygon'}},
#         #       ... more regions ...
#         #   },
#         #   'size': 100202
#         # }
#         # We mostly care about the x and y coordinates of each region
#         # Note: In VIA 2.0, regions was changed from a dict to a list.
#         annotations = json.load(open(os.path.join(dataset_dir, "annotation.json")))
#         annotations = list(annotations.values())  # don't need the dict keys

#         # The VIA tool saves images in the JSON even if they don't have any
#         # annotations. Skip unannotated images.
#         annotations = [a for a in annotations if a['regions']]

#         # Add images
#         for a in annotations:
#             # Get the x, y coordinaets of points of the polygons that make up
#             # the outline of each object instance. These are stores in the
#             # shape_attributes (see json format above)
#             # The if condition is needed to support VIA versions 1.x and 2.x.
#             if type(a['regions']) is dict:
#                 polygons = [r['shape_attributes'] for r in a['regions'].values()]
#             else:
#                 polygons = [r['shape_attributes'] for r in a['regions']] 

#             # load_mask() needs the image size to convert polygons to masks.
#             # Unfortunately, VIA doesn't include it in JSON, so we must read
#             # the image. This is only managable since the dataset is tiny.
#             image_path = os.path.join(dataset_dir, a['filename'])
#             image = skimage.io.imread(image_path,as_gray=True)
#             height, width = image.shape[:2]

#             self.add_image(
#                 "AbnormalType",
#                 image_id=a['filename'],  # use file name as a unique image id
#                 path=image_path,
#                 width=width, height=height,
#                 polygons=polygons)
    
#     def load_mask(self, image_id):
#         """Generate instance masks for an image.
#        Returns:
#         masks: A bool array of shape [height, width, instance count] with
#             one mask per instance.
#         class_ids: a 1D array of class IDs of the instance masks.
#         """
#         # If not a balloon dataset image, delegate to parent class.
#         info = self.image_info[image_id]
#         shapes = info['id']
#         #print(polygons)
#         #print(len(polygons))
#         #print(polygons[0]["name"])
        
#         count = len(info["polygons"])
#         #print(shapes)
#         #print(count)
#         mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        
#         for i, p in enumerate(info["polygons"]):
#             #print(p)
#             # Get indexes of pixels inside the polygon and set them to 1
#             rr, cc = skimage.draw.polygon(p['all_point_y'], p['all_point_x'])
#             mask[rr, cc, i] = 1
            
#         # Map class names to class IDs.
#         #print('shapes',shapes)
#         class_ids = np.array([self.class_names.index(info["polygons"][0]["name"])]*count)
#         return mask.astype(np.bool), class_ids.astype(np.int32)
#     def load_image(self, image_id):
#         """Load the specified image and return a [H,W,3] Numpy array.
#         """
#         # Load image
#         image = skimage.io.imread(self.image_info[image_id]['path'])
#         # If grayscale. Convert to RGB for consistency.
#         if image.ndim != 3:
#             image = skimage.color.gray2rgb(image)
#         # If has an alpha channel, remove it for consistency
#         if image.shape[-1] == 4:
#             image = image[..., :3]
#         image = image/255
#         return image

# %%
import json
import skimage
class CalcMassDataset_no_normalize(utils.Dataset):

    def load_full_mammo_img(self, dataset_dir, subset):
        """Load a subset of the Balloon dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        
        self.add_class("AbnormalType", 1, "Calc")
        self.add_class("AbnormalType", 2, "Mass")

        # Train or validation dataset?
        assert subset in ["Crop_train", "Crop_val","Crop_test"]
        dataset_dir = os.path.join(dataset_dir, subset)
        print("path join : " ,dataset_dir)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "annotation_skip02.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path,as_gray=True)
            height, width = image.shape[:2]

            self.add_image(
                "AbnormalType",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)
    
    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a balloon dataset image, delegate to parent class.
        info = self.image_info[image_id]
        shapes = info['id']
        #print(polygons)
        #print(len(polygons))
        #print(polygons[0]["name"])
        
        count = len(info["polygons"])
        #print(shapes)
        #print(count)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        
        for i, p in enumerate(info["polygons"]):
            #print(p)
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_point_y'], p['all_point_x'])
            mask[rr, cc, i] = 1
            
        # Map class names to class IDs.
        #print('shapes',shapes)
        class_ids = np.array([self.class_names.index(info["polygons"][0]["name"])]*count)
        return mask.astype(np.bool), class_ids.astype(np.int32)
    def load_image(self, image_id):
        """Load the specified image and return a [H,W,3] Numpy array.
        """
        # Load image
        image = skimage.io.imread(self.image_info[image_id]['path'])
        # If grayscale. Convert to RGB for consistency.
        if image.ndim != 3:
            image = skimage.color.gray2rgb(image)
        # If has an alpha channel, remove it for consistency
        if image.shape[-1] == 4:
            image = image[..., :3]
        return image

# %%
ROOT_DIR = r'E:\DataSet'
CALCMASS_DIR = os.path.join(ROOT_DIR, "CBIS-DDSM")

# Training dataset
dataset_train = CalcMassDataset_no_normalize()
dataset_train.load_full_mammo_img(CALCMASS_DIR, "Crop_train")
dataset_train.prepare()
print("Images: {}\nClasses: {}".format(len(dataset_train.image_ids), dataset_train.class_names))
# Out:
# path join :  E:\DataSet\CBIS-DDSM\Crop_train
# Images: 2355
# Classes: ['BG', 'Calc', 'Mass']

# %%
ROOT_DIR = r'E:\DataSet'
CALCMASS_DIR = os.path.join(ROOT_DIR, "CBIS-DDSM")

# Validation dataset
dataset_val = CalcMassDataset_no_normalize()
dataset_val.load_full_mammo_img(CALCMASS_DIR, "Crop_val")
dataset_val.prepare()

print("Images: {}\nClasses: {}".format(len(dataset_val.image_ids), dataset_val.class_names))
# Out:
# path join :  E:\DataSet\CBIS-DDSM\Crop_val
# Images: 523
# Classes: ['BG', 'Calc', 'Mass']

# %%
ROOT_DIR = r'E:\DataSet'
CALCMASS_DIR = os.path.join(ROOT_DIR, "CBIS-DDSM")

# Test dataset
dataset_test = CalcMassDataset_no_normalize()
dataset_test.load_full_mammo_img(CALCMASS_DIR, "Crop_test")
dataset_test.prepare()

print("Images: {}\nClasses: {}".format(len(dataset_test.image_ids), dataset_test.class_names))
# Out:
# path join :  E:\DataSet\CBIS-DDSM\Crop_test
# Images: 107
# Classes: ['BG', 'Calc', 'Mass']

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 2)

#4개의 랜덤이미지를 보여줌
for image_id in image_ids:
    print(image_id)
    
    image = dataset_train.load_image(image_id)
    info =dataset_train.image_info
    print(info[image_id]["path"])
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names,limit=1)
# Out:
# 584
# E:\DataSet\CBIS-DDSM\Crop_train\Calc-Training_P_00954_RIGHT_MLO_full.png
# 1646
# E:\DataSet\CBIS-DDSM\Crop_train\Mass-Training_P_00719_LEFT_MLO_full.png

# %%
image.shape
# Out:
# (3921, 2608, 3)

# %% [markdown]
# # Create & Tranning model_Tunning
# ---

# %%
class CalcMassConfig(Config):
    """
    Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 4

    # Number of classes (including background)
    NUM_CLASSES = 1 + 2  # background + 2 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_RESIZE_MODE = "square"
    IMAGE_MIN_DIM = 1024
    IMAGE_MAX_DIM = 1024
    IMAGE_CHANNEL_COUNT = 3
    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 200

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 10
    
config = CalcMassConfig()
#config.display()

# %%
# Create model in training mode
#all_model = modellib.MaskRCNN(mode="training", config=config,
#                          model_dir=MODEL_DIR)

# %% [markdown]
# ## CSV LOGGER 경로 및 파일명 확인!

# %%
# image augmentation
import imgaug
from time import time
# set callback
from keras import callbacks

ct_callback = [callbacks.TensorBoard(log_dir=r"E:/DataSet/logs/Tensorboard/{}".format(time())),
              callbacks.CSVLogger(r"E:/DataSet/logs/csv_log/200604_00_log.csv")]

# %%
# Create model in training mode
all_model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# Which weights to start with?
init_with = "last"  # imagenet, coco, or last

if init_with == "imagenet":
    all_model.load_weights(all_model.get_imagenet_weights(), by_name=True)
elif init_with == "last":
    # Load the last model you trained and continue training
    all_model.load_weights(all_model.find_last(), by_name=True)
# Out:
# Re-starting from epoch 200

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
all_model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=300,
            augmentation = imgaug.augmenters.Sometimes(0.5, [
                    imgaug.augmenters.Fliplr(0.5),
                    imgaug.augmenters.Flipud(0.5)]),
            custom_callbacks= ct_callback,
            layers='5+')
# Out:
# Starting at epoch 200. LR=0.001
#
# Checkpoint Path: D:\Codes\Mask_RCNN\logs\shapes20200530T0601\mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\Owner\Anaconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 201/300
# 200/200 [==============================] - 1475s 7s/step - loss: 1.3544 - rpn_class_loss: 0.0088 - rpn_bbox_loss: 0.6396 - mrcnn_class_loss: 0.1105 - mrcnn_bbox_loss: 0.1946 - mrcnn_mask_loss: 0.4009 - val_loss: 1.7694 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.6063 - val_mrcnn_class_loss: 0.1884 - val_mrcnn_bbox_loss: 0.3882 - val_mrcnn_mask_loss: 0.4352
# Epoch 202/300
# 200/200 [==============================] - 1470s 7s/step - loss: 1.3280 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.6121 - mrcnn_class_loss: 0.1169 - mrcnn_bbox_loss: 0.1883 - mrcnn_mask_loss: 0.4031 - val_loss: 2.2162 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 1.1932 - val_mrcnn_class_loss: 0.1442 - val_mrcnn_bbox_loss: 0.3982 - val_mrcnn_mask_loss: 0.4206
# Epoch 203/300
# 200/200 [==============================] - 1352s 7s/step - loss: 1.2701 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.5637 - mrcnn_class_loss: 0.1061 - mrcnn_bbox_loss: 0.1897 - mrcnn_mask_loss: 0.4038 - val_loss: 1.8194 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 1.2330 - val_mrcnn_class_loss: 0.1595 - val_mrcnn_bbox_loss: 0.4041 - val_mrcnn_mask_loss: 0.4011
# Epoch 204/300
# 200/200 [==============================] - 1491s 7s/step - loss: 1.3798 - rpn_class_loss: 0.0081 - rpn_bbox_loss: 0.6693 - mrcnn_class_loss: 0.1144 - mrcnn_bbox_loss: 0.1909 - mrcnn_mask_loss: 0.3971 - val_loss: 2.5014 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.6560 - val_mrcnn_class_loss: 0.1963 - val_mrcnn_bbox_loss: 0.4554 - val_mrcnn_mask_loss: 0.4412
# Epoch 205/300
# 200/200 [==============================] - 1406s 7s/step - loss: 1.2817 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.5575 - mrcnn_class_loss: 0.1173 - mrcnn_bbox_loss: 0.1946 - mrcnn_mask_loss: 0.4051 - val_loss: 1.9675 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.9793 - val_mrcnn_class_loss: 0.2079 - val_mrcnn_bbox_loss: 0.4335 - val_mrcnn_mask_loss: 0.4382
# Epoch 206/300
# 200/200 [==============================] - 1422s 7s/step - loss: 1.3391 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.6158 - mrcnn_class_loss: 0.1235 - mrcnn_bbox_loss: 0.1905 - mrcnn_mask_loss: 0.4020 - val_loss: 2.0207 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 1.4132 - val_mrcnn_class_loss: 0.1764 - val_mrcnn_bbox_loss: 0.4066 - val_mrcnn_mask_loss: 0.4114
# Epoch 207/300
# 200/200 [==============================] - 1511s 8s/step - loss: 1.3168 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.6000 - mrcnn_class_loss: 0.1121 - mrcnn_bbox_loss: 0.1962 - mrcnn_mask_loss: 0.4002 - val_loss: 2.6105 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.8516 - val_mrcnn_class_loss: 0.2739 - val_mrcnn_bbox_loss: 0.4371 - val_mrcnn_mask_loss: 0.4429
# Epoch 208/300
# 200/200 [==============================] - 1411s 7s/step - loss: 1.2635 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.5477 - mrcnn_class_loss: 0.1155 - mrcnn_bbox_loss: 0.1941 - mrcnn_mask_loss: 0.3989 - val_loss: 2.8806 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.8588 - val_mrcnn_class_loss: 0.2285 - val_mrcnn_bbox_loss: 0.3808 - val_mrcnn_mask_loss: 0.4278
# Epoch 209/300
# 200/200 [==============================] - 1365s 7s/step - loss: 1.2645 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.5493 - mrcnn_class_loss: 0.1092 - mrcnn_bbox_loss: 0.1919 - mrcnn_mask_loss: 0.4061 - val_loss: 1.9525 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.8356 - val_mrcnn_class_loss: 0.1481 - val_mrcnn_bbox_loss: 0.4039 - val_mrcnn_mask_loss: 0.4324
# Epoch 210/300
# 200/200 [==============================] - 1336s 7s/step - loss: 1.2308 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.5306 - mrcnn_class_loss: 0.1088 - mrcnn_bbox_loss: 0.1815 - mrcnn_mask_loss: 0.4026 - val_loss: 2.2675 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.8788 - val_mrcnn_class_loss: 0.2652 - val_mrcnn_bbox_loss: 0.4322 - val_mrcnn_mask_loss: 0.4566
# Epoch 211/300
# 200/200 [==============================] - 1406s 7s/step - loss: 1.2831 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.5793 - mrcnn_class_loss: 0.1092 - mrcnn_bbox_loss: 0.1852 - mrcnn_mask_loss: 0.4018 - val_loss: 1.7615 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.7547 - val_mrcnn_class_loss: 0.1834 - val_mrcnn_bbox_loss: 0.3895 - val_mrcnn_mask_loss: 0.4263
# Epoch 212/300
# 200/200 [==============================] - 1667s 8s/step - loss: 1.4917 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.7613 - mrcnn_class_loss: 0.1133 - mrcnn_bbox_loss: 0.2011 - mrcnn_mask_loss: 0.4064 - val_loss: 1.3826 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 1.3356 - val_mrcnn_class_loss: 0.1622 - val_mrcnn_bbox_loss: 0.4399 - val_mrcnn_mask_loss: 0.4711
# Epoch 213/300
# 200/200 [==============================] - 1442s 7s/step - loss: 1.2605 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.5718 - mrcnn_class_loss: 0.1041 - mrcnn_bbox_loss: 0.1806 - mrcnn_mask_loss: 0.3963 - val_loss: 1.6576 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.9277 - val_mrcnn_class_loss: 0.1461 - val_mrcnn_bbox_loss: 0.3982 - val_mrcnn_mask_loss: 0.4049
# Epoch 214/300
# 200/200 [==============================] - 1350s 7s/step - loss: 1.2298 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.5351 - mrcnn_class_loss: 0.1068 - mrcnn_bbox_loss: 0.1815 - mrcnn_mask_loss: 0.3990 - val_loss: 2.5184 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 1.1141 - val_mrcnn_class_loss: 0.2703 - val_mrcnn_bbox_loss: 0.4161 - val_mrcnn_mask_loss: 0.4486
# Epoch 215/300
# 200/200 [==============================] - 1349s 7s/step - loss: 1.2243 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.5171 - mrcnn_class_loss: 0.1097 - mrcnn_bbox_loss: 0.1846 - mrcnn_mask_loss: 0.4052 - val_loss: 1.7351 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.9350 - val_mrcnn_class_loss: 0.1921 - val_mrcnn_bbox_loss: 0.4771 - val_mrcnn_mask_loss: 0.4305
# Epoch 216/300
# 200/200 [==============================] - 1440s 7s/step - loss: 1.2513 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.5494 - mrcnn_class_loss: 0.1134 - mrcnn_bbox_loss: 0.1836 - mrcnn_mask_loss: 0.3979 - val_loss: 1.9321 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 1.0426 - val_mrcnn_class_loss: 0.1254 - val_mrcnn_bbox_loss: 0.4581 - val_mrcnn_mask_loss: 0.4573
# Epoch 217/300
# 200/200 [==============================] - 1414s 7s/step - loss: 1.2051 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.5056 - mrcnn_class_loss: 0.1080 - mrcnn_bbox_loss: 0.1859 - mrcnn_mask_loss: 0.3988 - val_loss: 1.9819 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 1.0119 - val_mrcnn_class_loss: 0.2699 - val_mrcnn_bbox_loss: 0.4528 - val_mrcnn_mask_loss: 0.4229
# Epoch 218/300
# 200/200 [==============================] - 1400s 7s/step - loss: 1.2507 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.5430 - mrcnn_class_loss: 0.1084 - mrcnn_bbox_loss: 0.1908 - mrcnn_mask_loss: 0.4011 - val_loss: 1.1170 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.8604 - val_mrcnn_class_loss: 0.1970 - val_mrcnn_bbox_loss: 0.3930 - val_mrcnn_mask_loss: 0.4426
# Epoch 219/300
# 200/200 [==============================] - 1418s 7s/step - loss: 1.2085 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.5023 - mrcnn_class_loss: 0.1120 - mrcnn_bbox_loss: 0.1854 - mrcnn_mask_loss: 0.4019 - val_loss: 2.3580 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.6815 - val_mrcnn_class_loss: 0.1467 - val_mrcnn_bbox_loss: 0.4002 - val_mrcnn_mask_loss: 0.4205
# Epoch 220/300
# 200/200 [==============================] - 1449s 7s/step - loss: 1.1951 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.5330 - mrcnn_class_loss: 0.0966 - mrcnn_bbox_loss: 0.1700 - mrcnn_mask_loss: 0.3878 - val_loss: 2.4440 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 1.0005 - val_mrcnn_class_loss: 0.2415 - val_mrcnn_bbox_loss: 0.4381 - val_mrcnn_mask_loss: 0.4376
# Epoch 221/300
# 200/200 [==============================] - 1543s 8s/step - loss: 1.2664 - rpn_class_loss: 0.0084 - rpn_bbox_loss: 0.5708 - mrcnn_class_loss: 0.1070 - mrcnn_bbox_loss: 0.1806 - mrcnn_mask_loss: 0.3996 - val_loss: 2.1892 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.8881 - val_mrcnn_class_loss: 0.2918 - val_mrcnn_bbox_loss: 0.4278 - val_mrcnn_mask_loss: 0.4613
# Epoch 222/300
# 200/200 [==============================] - 1335s 7s/step - loss: 1.1504 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.4810 - mrcnn_class_loss: 0.0990 - mrcnn_bbox_loss: 0.1747 - mrcnn_mask_loss: 0.3889 - val_loss: 1.3585 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 1.0649 - val_mrcnn_class_loss: 0.1985 - val_mrcnn_bbox_loss: 0.4475 - val_mrcnn_mask_loss: 0.4058
# Epoch 223/300
# 200/200 [==============================] - 1506s 8s/step - loss: 1.2682 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.5733 - mrcnn_class_loss: 0.1078 - mrcnn_bbox_loss: 0.1775 - mrcnn_mask_loss: 0.4020 - val_loss: 1.6194 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.7870 - val_mrcnn_class_loss: 0.2668 - val_mrcnn_bbox_loss: 0.3923 - val_mrcnn_mask_loss: 0.4289
# Epoch 224/300
# 200/200 [==============================] - 1413s 7s/step - loss: 1.1568 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.4546 - mrcnn_class_loss: 0.1144 - mrcnn_bbox_loss: 0.1787 - mrcnn_mask_loss: 0.4027 - val_loss: 1.7059 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.8659 - val_mrcnn_class_loss: 0.1496 - val_mrcnn_bbox_loss: 0.4491 - val_mrcnn_mask_loss: 0.4505
# Epoch 225/300
# 200/200 [==============================] - 1407s 7s/step - loss: 1.2598 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.5714 - mrcnn_class_loss: 0.1051 - mrcnn_bbox_loss: 0.1760 - mrcnn_mask_loss: 0.3998 - val_loss: 1.7381 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 1.1164 - val_mrcnn_class_loss: 0.1889 - val_mrcnn_bbox_loss: 0.3939 - val_mrcnn_mask_loss: 0.4261
# Epoch 226/300
# 200/200 [==============================] - 1424s 7s/step - loss: 1.1936 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5105 - mrcnn_class_loss: 0.1039 - mrcnn_bbox_loss: 0.1762 - mrcnn_mask_loss: 0.3957 - val_loss: 1.6479 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.9966 - val_mrcnn_class_loss: 0.2254 - val_mrcnn_bbox_loss: 0.3933 - val_mrcnn_mask_loss: 0.4221
# Epoch 227/300
# 200/200 [==============================] - 1387s 7s/step - loss: 1.2001 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5069 - mrcnn_class_loss: 0.1144 - mrcnn_bbox_loss: 0.1759 - mrcnn_mask_loss: 0.3954 - val_loss: 0.9144 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.7321 - val_mrcnn_class_loss: 0.2609 - val_mrcnn_bbox_loss: 0.4507 - val_mrcnn_mask_loss: 0.4751
# Epoch 228/300
# 200/200 [==============================] - 1437s 7s/step - loss: 1.2359 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.5357 - mrcnn_class_loss: 0.1099 - mrcnn_bbox_loss: 0.1859 - mrcnn_mask_loss: 0.3973 - val_loss: 4.8332 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 1.3146 - val_mrcnn_class_loss: 0.2478 - val_mrcnn_bbox_loss: 0.4418 - val_mrcnn_mask_loss: 0.4589
# Epoch 229/300
# 200/200 [==============================] - 1517s 8s/step - loss: 1.2734 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.5812 - mrcnn_class_loss: 0.1053 - mrcnn_bbox_loss: 0.1823 - mrcnn_mask_loss: 0.3966 - val_loss: 1.7541 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.9741 - val_mrcnn_class_loss: 0.3248 - val_mrcnn_bbox_loss: 0.3951 - val_mrcnn_mask_loss: 0.4192
# Epoch 230/300
# 200/200 [==============================] - 1363s 7s/step - loss: 1.1921 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.5046 - mrcnn_class_loss: 0.1041 - mrcnn_bbox_loss: 0.1767 - mrcnn_mask_loss: 0.3999 - val_loss: 1.7153 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.8163 - val_mrcnn_class_loss: 0.1998 - val_mrcnn_bbox_loss: 0.4632 - val_mrcnn_mask_loss: 0.4470
# Epoch 231/300
# 200/200 [==============================] - 1436s 7s/step - loss: 1.2180 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5531 - mrcnn_class_loss: 0.0948 - mrcnn_bbox_loss: 0.1687 - mrcnn_mask_loss: 0.3939 - val_loss: 3.3584 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 1.3812 - val_mrcnn_class_loss: 0.1895 - val_mrcnn_bbox_loss: 0.4807 - val_mrcnn_mask_loss: 0.5200
# Epoch 232/300
# 200/200 [==============================] - 1359s 7s/step - loss: 1.2369 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.5521 - mrcnn_class_loss: 0.1018 - mrcnn_bbox_loss: 0.1786 - mrcnn_mask_loss: 0.3974 - val_loss: 2.6618 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 1.2554 - val_mrcnn_class_loss: 0.1653 - val_mrcnn_bbox_loss: 0.4264 - val_mrcnn_mask_loss: 0.4177
# Epoch 233/300
# 200/200 [==============================] - 1437s 7s/step - loss: 1.2159 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.5376 - mrcnn_class_loss: 0.1067 - mrcnn_bbox_loss: 0.1738 - mrcnn_mask_loss: 0.3909 - val_loss: 2.1164 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.8898 - val_mrcnn_class_loss: 0.1492 - val_mrcnn_bbox_loss: 0.4263 - val_mrcnn_mask_loss: 0.4172
# Epoch 234/300
# 200/200 [==============================] - 1375s 7s/step - loss: 1.2307 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5607 - mrcnn_class_loss: 0.1020 - mrcnn_bbox_loss: 0.1718 - mrcnn_mask_loss: 0.3884 - val_loss: 3.3693 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 1.1363 - val_mrcnn_class_loss: 0.1790 - val_mrcnn_bbox_loss: 0.4037 - val_mrcnn_mask_loss: 0.4050
# Epoch 235/300
# 200/200 [==============================] - 1450s 7s/step - loss: 1.1333 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.4542 - mrcnn_class_loss: 0.1000 - mrcnn_bbox_loss: 0.1740 - mrcnn_mask_loss: 0.3976 - val_loss: 2.1623 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.6893 - val_mrcnn_class_loss: 0.1698 - val_mrcnn_bbox_loss: 0.4222 - val_mrcnn_mask_loss: 0.4200
# Epoch 236/300
# 200/200 [==============================] - 1387s 7s/step - loss: 1.1415 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4682 - mrcnn_class_loss: 0.0957 - mrcnn_bbox_loss: 0.1703 - mrcnn_mask_loss: 0.4002 - val_loss: 2.1025 - val_rpn_class_loss: 0.0053 - val_rpn_bbox_loss: 0.7624 - val_mrcnn_class_loss: 0.1829 - val_mrcnn_bbox_loss: 0.3973 - val_mrcnn_mask_loss: 0.4001
# Epoch 237/300
# 200/200 [==============================] - 1453s 7s/step - loss: 1.2261 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.5544 - mrcnn_class_loss: 0.1012 - mrcnn_bbox_loss: 0.1742 - mrcnn_mask_loss: 0.3891 - val_loss: 1.9778 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.9517 - val_mrcnn_class_loss: 0.1342 - val_mrcnn_bbox_loss: 0.3932 - val_mrcnn_mask_loss: 0.4158
# Epoch 238/300
# 200/200 [==============================] - 1426s 7s/step - loss: 1.2318 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.5476 - mrcnn_class_loss: 0.1097 - mrcnn_bbox_loss: 0.1740 - mrcnn_mask_loss: 0.3931 - val_loss: 2.9073 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 1.1956 - val_mrcnn_class_loss: 0.1828 - val_mrcnn_bbox_loss: 0.4114 - val_mrcnn_mask_loss: 0.4367
# Epoch 239/300
# 200/200 [==============================] - 1503s 8s/step - loss: 1.1917 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.5154 - mrcnn_class_loss: 0.1010 - mrcnn_bbox_loss: 0.1743 - mrcnn_mask_loss: 0.3930 - val_loss: 1.2706 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 1.0451 - val_mrcnn_class_loss: 0.2320 - val_mrcnn_bbox_loss: 0.4023 - val_mrcnn_mask_loss: 0.4534
# Epoch 240/300
# 200/200 [==============================] - 1449s 7s/step - loss: 1.1633 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.5027 - mrcnn_class_loss: 0.0966 - mrcnn_bbox_loss: 0.1620 - mrcnn_mask_loss: 0.3942 - val_loss: 1.1875 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 1.2491 - val_mrcnn_class_loss: 0.1181 - val_mrcnn_bbox_loss: 0.4114 - val_mrcnn_mask_loss: 0.4270
# Epoch 241/300
# 200/200 [==============================] - 1382s 7s/step - loss: 1.1720 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.5029 - mrcnn_class_loss: 0.0989 - mrcnn_bbox_loss: 0.1742 - mrcnn_mask_loss: 0.3893 - val_loss: 1.4919 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.9911 - val_mrcnn_class_loss: 0.2133 - val_mrcnn_bbox_loss: 0.4077 - val_mrcnn_mask_loss: 0.4082
# Epoch 242/300
# 200/200 [==============================] - 1385s 7s/step - loss: 1.1633 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.4922 - mrcnn_class_loss: 0.1017 - mrcnn_bbox_loss: 0.1669 - mrcnn_mask_loss: 0.3952 - val_loss: 1.5988 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.6906 - val_mrcnn_class_loss: 0.1659 - val_mrcnn_bbox_loss: 0.3894 - val_mrcnn_mask_loss: 0.4246
# Epoch 243/300
# 200/200 [==============================] - 1412s 7s/step - loss: 1.1271 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.4674 - mrcnn_class_loss: 0.0969 - mrcnn_bbox_loss: 0.1667 - mrcnn_mask_loss: 0.3890 - val_loss: 4.0059 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 1.1178 - val_mrcnn_class_loss: 0.1651 - val_mrcnn_bbox_loss: 0.4529 - val_mrcnn_mask_loss: 0.5034
# Epoch 244/300
# 200/200 [==============================] - 1483s 7s/step - loss: 1.2398 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5785 - mrcnn_class_loss: 0.0978 - mrcnn_bbox_loss: 0.1660 - mrcnn_mask_loss: 0.3897 - val_loss: 1.3739 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.9952 - val_mrcnn_class_loss: 0.2786 - val_mrcnn_bbox_loss: 0.3985 - val_mrcnn_mask_loss: 0.4050
# Epoch 245/300
# 200/200 [==============================] - 1381s 7s/step - loss: 1.1110 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.4573 - mrcnn_class_loss: 0.1004 - mrcnn_bbox_loss: 0.1611 - mrcnn_mask_loss: 0.3850 - val_loss: 1.8470 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 1.0908 - val_mrcnn_class_loss: 0.2710 - val_mrcnn_bbox_loss: 0.4493 - val_mrcnn_mask_loss: 0.4850
# Epoch 246/300
# 200/200 [==============================] - 1414s 7s/step - loss: 1.2052 - rpn_class_loss: 0.0081 - rpn_bbox_loss: 0.5399 - mrcnn_class_loss: 0.1016 - mrcnn_bbox_loss: 0.1667 - mrcnn_mask_loss: 0.3889 - val_loss: 2.2294 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.7207 - val_mrcnn_class_loss: 0.2154 - val_mrcnn_bbox_loss: 0.4106 - val_mrcnn_mask_loss: 0.4114
# Epoch 247/300
# 200/200 [==============================] - 1354s 7s/step - loss: 1.1289 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.4775 - mrcnn_class_loss: 0.0952 - mrcnn_bbox_loss: 0.1577 - mrcnn_mask_loss: 0.3920 - val_loss: 2.0231 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.8374 - val_mrcnn_class_loss: 0.2186 - val_mrcnn_bbox_loss: 0.4539 - val_mrcnn_mask_loss: 0.4434
# Epoch 248/300
# 200/200 [==============================] - 1551s 8s/step - loss: 1.1940 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.5286 - mrcnn_class_loss: 0.1030 - mrcnn_bbox_loss: 0.1673 - mrcnn_mask_loss: 0.3874 - val_loss: 1.6886 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.9280 - val_mrcnn_class_loss: 0.1934 - val_mrcnn_bbox_loss: 0.4245 - val_mrcnn_mask_loss: 0.4622
# Epoch 249/300
# 200/200 [==============================] - 1354s 7s/step - loss: 1.1438 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.4764 - mrcnn_class_loss: 0.0980 - mrcnn_bbox_loss: 0.1668 - mrcnn_mask_loss: 0.3950 - val_loss: 2.5446 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.8552 - val_mrcnn_class_loss: 0.3112 - val_mrcnn_bbox_loss: 0.5012 - val_mrcnn_mask_loss: 0.5186
# Epoch 250/300
# 200/200 [==============================] - 1420s 7s/step - loss: 1.1948 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.5215 - mrcnn_class_loss: 0.1036 - mrcnn_bbox_loss: 0.1674 - mrcnn_mask_loss: 0.3944 - val_loss: 1.7492 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 1.0015 - val_mrcnn_class_loss: 0.2874 - val_mrcnn_bbox_loss: 0.4658 - val_mrcnn_mask_loss: 0.4628
# Epoch 251/300
# 200/200 [==============================] - 1379s 7s/step - loss: 1.1514 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.5001 - mrcnn_class_loss: 0.0916 - mrcnn_bbox_loss: 0.1609 - mrcnn_mask_loss: 0.3918 - val_loss: 2.9506 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 1.1409 - val_mrcnn_class_loss: 0.1766 - val_mrcnn_bbox_loss: 0.4121 - val_mrcnn_mask_loss: 0.4273
# Epoch 252/300
# 200/200 [==============================] - 1359s 7s/step - loss: 1.1221 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4615 - mrcnn_class_loss: 0.0971 - mrcnn_bbox_loss: 0.1642 - mrcnn_mask_loss: 0.3924 - val_loss: 1.1555 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.8812 - val_mrcnn_class_loss: 0.2135 - val_mrcnn_bbox_loss: 0.3725 - val_mrcnn_mask_loss: 0.4174
# Epoch 253/300
# 200/200 [==============================] - 1477s 7s/step - loss: 1.2176 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5462 - mrcnn_class_loss: 0.1005 - mrcnn_bbox_loss: 0.1697 - mrcnn_mask_loss: 0.3939 - val_loss: 2.8815 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 1.2358 - val_mrcnn_class_loss: 0.1704 - val_mrcnn_bbox_loss: 0.4229 - val_mrcnn_mask_loss: 0.4194
# Epoch 254/300
# 200/200 [==============================] - 1433s 7s/step - loss: 1.1055 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.4508 - mrcnn_class_loss: 0.0941 - mrcnn_bbox_loss: 0.1653 - mrcnn_mask_loss: 0.3879 - val_loss: 1.6772 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 1.0013 - val_mrcnn_class_loss: 0.1928 - val_mrcnn_bbox_loss: 0.3643 - val_mrcnn_mask_loss: 0.4237
# Epoch 255/300
# 200/200 [==============================] - 1358s 7s/step - loss: 1.1079 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4460 - mrcnn_class_loss: 0.0987 - mrcnn_bbox_loss: 0.1634 - mrcnn_mask_loss: 0.3929 - val_loss: 1.9395 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.7146 - val_mrcnn_class_loss: 0.2717 - val_mrcnn_bbox_loss: 0.4549 - val_mrcnn_mask_loss: 0.4746
# Epoch 256/300
# 200/200 [==============================] - 1500s 8s/step - loss: 1.1527 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.4942 - mrcnn_class_loss: 0.1002 - mrcnn_bbox_loss: 0.1650 - mrcnn_mask_loss: 0.3856 - val_loss: 1.9658 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 1.0244 - val_mrcnn_class_loss: 0.1951 - val_mrcnn_bbox_loss: 0.4602 - val_mrcnn_mask_loss: 0.4511
# Epoch 257/300
# 200/200 [==============================] - 1548s 8s/step - loss: 1.1725 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.5141 - mrcnn_class_loss: 0.0968 - mrcnn_bbox_loss: 0.1658 - mrcnn_mask_loss: 0.3886 - val_loss: 3.4089 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 1.2102 - val_mrcnn_class_loss: 0.1847 - val_mrcnn_bbox_loss: 0.4279 - val_mrcnn_mask_loss: 0.4255
# Epoch 258/300
# 200/200 [==============================] - 1352s 7s/step - loss: 1.1329 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.4890 - mrcnn_class_loss: 0.0888 - mrcnn_bbox_loss: 0.1610 - mrcnn_mask_loss: 0.3866 - val_loss: 1.3772 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.9938 - val_mrcnn_class_loss: 0.1677 - val_mrcnn_bbox_loss: 0.4812 - val_mrcnn_mask_loss: 0.4222
# Epoch 259/300
# 200/200 [==============================] - 1355s 7s/step - loss: 1.0946 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.4378 - mrcnn_class_loss: 0.0950 - mrcnn_bbox_loss: 0.1674 - mrcnn_mask_loss: 0.3870 - val_loss: 2.5692 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.8944 - val_mrcnn_class_loss: 0.2435 - val_mrcnn_bbox_loss: 0.4271 - val_mrcnn_mask_loss: 0.4475
# Epoch 260/300
# 200/200 [==============================] - 1492s 7s/step - loss: 1.2244 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5485 - mrcnn_class_loss: 0.0994 - mrcnn_bbox_loss: 0.1720 - mrcnn_mask_loss: 0.3966 - val_loss: 2.5380 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 1.1511 - val_mrcnn_class_loss: 0.1867 - val_mrcnn_bbox_loss: 0.4454 - val_mrcnn_mask_loss: 0.4583
# Epoch 261/300
# 200/200 [==============================] - 1334s 7s/step - loss: 1.0398 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.3993 - mrcnn_class_loss: 0.0979 - mrcnn_bbox_loss: 0.1551 - mrcnn_mask_loss: 0.3808 - val_loss: 2.3420 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 1.2886 - val_mrcnn_class_loss: 0.2045 - val_mrcnn_bbox_loss: 0.5124 - val_mrcnn_mask_loss: 0.4849
# Epoch 262/300
# 200/200 [==============================] - 1467s 7s/step - loss: 1.1616 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.4985 - mrcnn_class_loss: 0.0997 - mrcnn_bbox_loss: 0.1655 - mrcnn_mask_loss: 0.3915 - val_loss: 1.4339 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.7637 - val_mrcnn_class_loss: 0.2462 - val_mrcnn_bbox_loss: 0.3878 - val_mrcnn_mask_loss: 0.3760
# Epoch 263/300
# 200/200 [==============================] - 1357s 7s/step - loss: 1.0878 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.4546 - mrcnn_class_loss: 0.0886 - mrcnn_bbox_loss: 0.1542 - mrcnn_mask_loss: 0.3833 - val_loss: 1.0819 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.7084 - val_mrcnn_class_loss: 0.1109 - val_mrcnn_bbox_loss: 0.3338 - val_mrcnn_mask_loss: 0.4022
# Epoch 264/300
# 200/200 [==============================] - 1284s 6s/step - loss: 1.0610 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.4189 - mrcnn_class_loss: 0.0895 - mrcnn_bbox_loss: 0.1536 - mrcnn_mask_loss: 0.3922 - val_loss: 1.7911 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.9078 - val_mrcnn_class_loss: 0.2802 - val_mrcnn_bbox_loss: 0.4269 - val_mrcnn_mask_loss: 0.4237
# Epoch 265/300
# 200/200 [==============================] - 1517s 8s/step - loss: 1.1888 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.5422 - mrcnn_class_loss: 0.0957 - mrcnn_bbox_loss: 0.1610 - mrcnn_mask_loss: 0.3824 - val_loss: 1.6014 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 1.1718 - val_mrcnn_class_loss: 0.2501 - val_mrcnn_bbox_loss: 0.4567 - val_mrcnn_mask_loss: 0.4358
# Epoch 266/300
# 200/200 [==============================] - 1483s 7s/step - loss: 1.1111 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4696 - mrcnn_class_loss: 0.0892 - mrcnn_bbox_loss: 0.1581 - mrcnn_mask_loss: 0.3874 - val_loss: 1.4165 - val_rpn_class_loss: 0.0053 - val_rpn_bbox_loss: 0.8882 - val_mrcnn_class_loss: 0.1754 - val_mrcnn_bbox_loss: 0.3713 - val_mrcnn_mask_loss: 0.4635
# Epoch 267/300
# 200/200 [==============================] - 1399s 7s/step - loss: 1.1683 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5269 - mrcnn_class_loss: 0.0949 - mrcnn_bbox_loss: 0.1549 - mrcnn_mask_loss: 0.3838 - val_loss: 2.0303 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 1.2970 - val_mrcnn_class_loss: 0.1986 - val_mrcnn_bbox_loss: 0.4355 - val_mrcnn_mask_loss: 0.4582
# Epoch 268/300
# 200/200 [==============================] - 1412s 7s/step - loss: 1.1580 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5029 - mrcnn_class_loss: 0.0899 - mrcnn_bbox_loss: 0.1622 - mrcnn_mask_loss: 0.3956 - val_loss: 1.3353 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 1.1977 - val_mrcnn_class_loss: 0.2075 - val_mrcnn_bbox_loss: 0.4759 - val_mrcnn_mask_loss: 0.4663
# Epoch 269/300
# 200/200 [==============================] - 1298s 6s/step - loss: 1.0291 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.4040 - mrcnn_class_loss: 0.0887 - mrcnn_bbox_loss: 0.1502 - mrcnn_mask_loss: 0.3796 - val_loss: 1.4540 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 1.0559 - val_mrcnn_class_loss: 0.1819 - val_mrcnn_bbox_loss: 0.4273 - val_mrcnn_mask_loss: 0.4103
# Epoch 270/300
# 200/200 [==============================] - 1443s 7s/step - loss: 1.1162 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.4741 - mrcnn_class_loss: 0.0895 - mrcnn_bbox_loss: 0.1575 - mrcnn_mask_loss: 0.3878 - val_loss: 3.1445 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 1.0635 - val_mrcnn_class_loss: 0.1594 - val_mrcnn_bbox_loss: 0.3737 - val_mrcnn_mask_loss: 0.3996
# Epoch 271/300
# 200/200 [==============================] - 1501s 8s/step - loss: 1.2164 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5658 - mrcnn_class_loss: 0.0959 - mrcnn_bbox_loss: 0.1637 - mrcnn_mask_loss: 0.3832 - val_loss: 2.9035 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 1.1151 - val_mrcnn_class_loss: 0.2575 - val_mrcnn_bbox_loss: 0.4149 - val_mrcnn_mask_loss: 0.4780
# Epoch 272/300
# 200/200 [==============================] - 1403s 7s/step - loss: 1.0421 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.4114 - mrcnn_class_loss: 0.0917 - mrcnn_bbox_loss: 0.1514 - mrcnn_mask_loss: 0.3802 - val_loss: 4.8529 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 1.1393 - val_mrcnn_class_loss: 0.2366 - val_mrcnn_bbox_loss: 0.3779 - val_mrcnn_mask_loss: 0.4032
# Epoch 273/300
# 200/200 [==============================] - 1449s 7s/step - loss: 1.1119 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4634 - mrcnn_class_loss: 0.0949 - mrcnn_bbox_loss: 0.1582 - mrcnn_mask_loss: 0.3886 - val_loss: 2.3372 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 1.0081 - val_mrcnn_class_loss: 0.1896 - val_mrcnn_bbox_loss: 0.4726 - val_mrcnn_mask_loss: 0.4702
# Epoch 274/300
# 200/200 [==============================] - 1321s 7s/step - loss: 1.0099 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.3816 - mrcnn_class_loss: 0.0880 - mrcnn_bbox_loss: 0.1536 - mrcnn_mask_loss: 0.3805 - val_loss: 2.0531 - val_rpn_class_loss: 0.0062 - val_rpn_bbox_loss: 0.9198 - val_mrcnn_class_loss: 0.3298 - val_mrcnn_bbox_loss: 0.4533 - val_mrcnn_mask_loss: 0.4547
# Epoch 275/300
# 200/200 [==============================] - 1429s 7s/step - loss: 1.1059 - rpn_class_loss: 0.0081 - rpn_bbox_loss: 0.4611 - mrcnn_class_loss: 0.0957 - mrcnn_bbox_loss: 0.1544 - mrcnn_mask_loss: 0.3866 - val_loss: 2.5415 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.9043 - val_mrcnn_class_loss: 0.2516 - val_mrcnn_bbox_loss: 0.4197 - val_mrcnn_mask_loss: 0.4549
# Epoch 276/300
# 200/200 [==============================] - 1426s 7s/step - loss: 1.1487 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.5088 - mrcnn_class_loss: 0.0949 - mrcnn_bbox_loss: 0.1552 - mrcnn_mask_loss: 0.3823 - val_loss: 2.1147 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.7807 - val_mrcnn_class_loss: 0.1711 - val_mrcnn_bbox_loss: 0.3854 - val_mrcnn_mask_loss: 0.3988
# Epoch 277/300
# 200/200 [==============================] - 1443s 7s/step - loss: 1.0851 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4534 - mrcnn_class_loss: 0.0832 - mrcnn_bbox_loss: 0.1552 - mrcnn_mask_loss: 0.3864 - val_loss: 1.6005 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 1.0638 - val_mrcnn_class_loss: 0.2385 - val_mrcnn_bbox_loss: 0.4304 - val_mrcnn_mask_loss: 0.4387
# Epoch 278/300
# 200/200 [==============================] - 1492s 7s/step - loss: 1.0979 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4665 - mrcnn_class_loss: 0.0943 - mrcnn_bbox_loss: 0.1494 - mrcnn_mask_loss: 0.3807 - val_loss: 1.5326 - val_rpn_class_loss: 0.0064 - val_rpn_bbox_loss: 0.9359 - val_mrcnn_class_loss: 0.1477 - val_mrcnn_bbox_loss: 0.4835 - val_mrcnn_mask_loss: 0.4829
# Epoch 279/300
# 200/200 [==============================] - 1369s 7s/step - loss: 1.0487 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.4218 - mrcnn_class_loss: 0.0905 - mrcnn_bbox_loss: 0.1507 - mrcnn_mask_loss: 0.3785 - val_loss: 1.4756 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 1.1420 - val_mrcnn_class_loss: 0.1502 - val_mrcnn_bbox_loss: 0.4028 - val_mrcnn_mask_loss: 0.4446
# Epoch 280/300
# 200/200 [==============================] - 1474s 7s/step - loss: 1.1847 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.5296 - mrcnn_class_loss: 0.0966 - mrcnn_bbox_loss: 0.1627 - mrcnn_mask_loss: 0.3884 - val_loss: 1.9734 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.8908 - val_mrcnn_class_loss: 0.2859 - val_mrcnn_bbox_loss: 0.4429 - val_mrcnn_mask_loss: 0.4317
# Epoch 281/300
# 200/200 [==============================] - 1337s 7s/step - loss: 1.0111 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.3865 - mrcnn_class_loss: 0.0882 - mrcnn_bbox_loss: 0.1464 - mrcnn_mask_loss: 0.3833 - val_loss: 1.5747 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 1.1428 - val_mrcnn_class_loss: 0.1526 - val_mrcnn_bbox_loss: 0.4792 - val_mrcnn_mask_loss: 0.4690
# Epoch 282/300
# 200/200 [==============================] - 1414s 7s/step - loss: 1.0666 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.4416 - mrcnn_class_loss: 0.0905 - mrcnn_bbox_loss: 0.1548 - mrcnn_mask_loss: 0.3730 - val_loss: 2.0461 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.9431 - val_mrcnn_class_loss: 0.3438 - val_mrcnn_bbox_loss: 0.4559 - val_mrcnn_mask_loss: 0.4201
# Epoch 283/300
# 200/200 [==============================] - 1483s 7s/step - loss: 1.1547 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.5079 - mrcnn_class_loss: 0.0974 - mrcnn_bbox_loss: 0.1547 - mrcnn_mask_loss: 0.3867 - val_loss: 2.1061 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 1.1771 - val_mrcnn_class_loss: 0.3114 - val_mrcnn_bbox_loss: 0.4686 - val_mrcnn_mask_loss: 0.4684
# Epoch 284/300
# 200/200 [==============================] - 1387s 7s/step - loss: 1.0738 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4385 - mrcnn_class_loss: 0.0948 - mrcnn_bbox_loss: 0.1500 - mrcnn_mask_loss: 0.3835 - val_loss: 1.6727 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.9941 - val_mrcnn_class_loss: 0.1850 - val_mrcnn_bbox_loss: 0.4087 - val_mrcnn_mask_loss: 0.4224
# Epoch 285/300
# 200/200 [==============================] - 1413s 7s/step - loss: 1.0218 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.3933 - mrcnn_class_loss: 0.0918 - mrcnn_bbox_loss: 0.1522 - mrcnn_mask_loss: 0.3784 - val_loss: 2.2916 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 1.1609 - val_mrcnn_class_loss: 0.1271 - val_mrcnn_bbox_loss: 0.4633 - val_mrcnn_mask_loss: 0.4839
# Epoch 286/300
# 200/200 [==============================] - 1511s 8s/step - loss: 1.0915 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.4583 - mrcnn_class_loss: 0.0908 - mrcnn_bbox_loss: 0.1546 - mrcnn_mask_loss: 0.3807 - val_loss: 2.1569 - val_rpn_class_loss: 0.0044 - val_rpn_bbox_loss: 0.9119 - val_mrcnn_class_loss: 0.2336 - val_mrcnn_bbox_loss: 0.4372 - val_mrcnn_mask_loss: 0.4860
# Epoch 287/300
# 200/200 [==============================] - 1445s 7s/step - loss: 1.0556 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.4274 - mrcnn_class_loss: 0.0912 - mrcnn_bbox_loss: 0.1520 - mrcnn_mask_loss: 0.3784 - val_loss: 3.4720 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 1.1071 - val_mrcnn_class_loss: 0.1365 - val_mrcnn_bbox_loss: 0.4902 - val_mrcnn_mask_loss: 0.4651
# Epoch 288/300
# 200/200 [==============================] - 1359s 7s/step - loss: 1.1020 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.4587 - mrcnn_class_loss: 0.0959 - mrcnn_bbox_loss: 0.1550 - mrcnn_mask_loss: 0.3852 - val_loss: 2.2122 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.7389 - val_mrcnn_class_loss: 0.2231 - val_mrcnn_bbox_loss: 0.4130 - val_mrcnn_mask_loss: 0.4122
# Epoch 289/300
# 200/200 [==============================] - 1442s 7s/step - loss: 1.1219 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.4905 - mrcnn_class_loss: 0.0906 - mrcnn_bbox_loss: 0.1545 - mrcnn_mask_loss: 0.3794 - val_loss: 2.0361 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.8536 - val_mrcnn_class_loss: 0.2266 - val_mrcnn_bbox_loss: 0.4506 - val_mrcnn_mask_loss: 0.4429
# Epoch 290/300
# 200/200 [==============================] - 1422s 7s/step - loss: 1.0246 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.4063 - mrcnn_class_loss: 0.0854 - mrcnn_bbox_loss: 0.1454 - mrcnn_mask_loss: 0.3807 - val_loss: 2.4412 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 1.2376 - val_mrcnn_class_loss: 0.1725 - val_mrcnn_bbox_loss: 0.4306 - val_mrcnn_mask_loss: 0.4211
# Epoch 291/300
# 200/200 [==============================] - 1360s 7s/step - loss: 1.0855 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.4508 - mrcnn_class_loss: 0.0886 - mrcnn_bbox_loss: 0.1580 - mrcnn_mask_loss: 0.3810 - val_loss: 2.1394 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.9498 - val_mrcnn_class_loss: 0.2220 - val_mrcnn_bbox_loss: 0.3725 - val_mrcnn_mask_loss: 0.4196
# Epoch 292/300
# 200/200 [==============================] - 1399s 7s/step - loss: 1.0408 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.4195 - mrcnn_class_loss: 0.0859 - mrcnn_bbox_loss: 0.1465 - mrcnn_mask_loss: 0.3825 - val_loss: 1.3084 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 1.0828 - val_mrcnn_class_loss: 0.1489 - val_mrcnn_bbox_loss: 0.4092 - val_mrcnn_mask_loss: 0.3862
# Epoch 293/300
# 200/200 [==============================] - 1439s 7s/step - loss: 1.0278 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.4008 - mrcnn_class_loss: 0.0877 - mrcnn_bbox_loss: 0.1530 - mrcnn_mask_loss: 0.3798 - val_loss: 2.2075 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 1.0235 - val_mrcnn_class_loss: 0.2916 - val_mrcnn_bbox_loss: 0.4103 - val_mrcnn_mask_loss: 0.4361
# Epoch 294/300
# 200/200 [==============================] - 1434s 7s/step - loss: 1.0907 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.4548 - mrcnn_class_loss: 0.0940 - mrcnn_bbox_loss: 0.1518 - mrcnn_mask_loss: 0.3826 - val_loss: 1.8876 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.9105 - val_mrcnn_class_loss: 0.2185 - val_mrcnn_bbox_loss: 0.4201 - val_mrcnn_mask_loss: 0.4270
# Epoch 295/300
# 200/200 [==============================] - 1332s 7s/step - loss: 1.0098 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.3869 - mrcnn_class_loss: 0.0887 - mrcnn_bbox_loss: 0.1473 - mrcnn_mask_loss: 0.3799 - val_loss: 2.1537 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.7449 - val_mrcnn_class_loss: 0.2427 - val_mrcnn_bbox_loss: 0.4362 - val_mrcnn_mask_loss: 0.4183
# Epoch 296/300
# 200/200 [==============================] - 1445s 7s/step - loss: 1.0392 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.4160 - mrcnn_class_loss: 0.0877 - mrcnn_bbox_loss: 0.1486 - mrcnn_mask_loss: 0.3801 - val_loss: 1.9667 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.8676 - val_mrcnn_class_loss: 0.1967 - val_mrcnn_bbox_loss: 0.4692 - val_mrcnn_mask_loss: 0.5377
# Epoch 297/300
# 200/200 [==============================] - 1430s 7s/step - loss: 1.1464 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.5012 - mrcnn_class_loss: 0.0940 - mrcnn_bbox_loss: 0.1593 - mrcnn_mask_loss: 0.3840 - val_loss: 1.6628 - val_rpn_class_loss: 0.0058 - val_rpn_bbox_loss: 0.8363 - val_mrcnn_class_loss: 0.1989 - val_mrcnn_bbox_loss: 0.4332 - val_mrcnn_mask_loss: 0.4331
# Epoch 298/300
# 200/200 [==============================] - 1387s 7s/step - loss: 1.1219 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.5025 - mrcnn_class_loss: 0.0854 - mrcnn_bbox_loss: 0.1509 - mrcnn_mask_loss: 0.3761 - val_loss: 2.4415 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 1.0225 - val_mrcnn_class_loss: 0.2266 - val_mrcnn_bbox_loss: 0.4453 - val_mrcnn_mask_loss: 0.4205
# Epoch 299/300
# 200/200 [==============================] - 1231s 6s/step - loss: 0.9092 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.3061 - mrcnn_class_loss: 0.0780 - mrcnn_bbox_loss: 0.1430 - mrcnn_mask_loss: 0.3761 - val_loss: 1.8254 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 1.0035 - val_mrcnn_class_loss: 0.2861 - val_mrcnn_bbox_loss: 0.3868 - val_mrcnn_mask_loss: 0.4480
# Epoch 300/300
# 200/200 [==============================] - 1610s 8s/step - loss: 1.1227 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.4984 - mrcnn_class_loss: 0.0907 - mrcnn_bbox_loss: 0.1453 - mrcnn_mask_loss: 0.3798 - val_loss: 1.5114 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 1.1400 - val_mrcnn_class_loss: 0.2169 - val_mrcnn_bbox_loss: 0.3998 - val_mrcnn_mask_loss: 0.4418

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
all_model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=10,
            augmentation = imgaug.augmenters.Sometimes(0.5, [
                    imgaug.augmenters.Fliplr(0.5),
                    imgaug.augmenters.Flipud(0.5)]),
            custom_callbacks= ct_callback,
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: D:\Gproject\Codes\Mask_RCNN_1.14\logs\shapes20200530T0425\mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\tensorflow\python\ops\gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\micke\Miniconda3\envs\mrcnn\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/10
#  6/50 [==>...........................] - ETA: 3:46 - loss: 4.6024 - rpn_class_loss: 1.3500 - rpn_bbox_loss: 2.8701 - mrcnn_class_loss: 0.3822 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-85f601d0da50> in <module>
#      10                     imgaug.augmenters.Flipud(0.5)]),
#      11             custom_callbacks= ct_callback,
# ---> 12             layers='heads')
#
# D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py in train(self, train_dataset, val_dataset, learning_rate, epochs, layers, augmentation, custom_callbacks, no_augmentation_sources)
#    2373             max_queue_size=100,
#    2374             workers=workers,
# -> 2375             use_multiprocessing=True,
#    2376         )
#    2377         self.epoch = max(self.epoch, epochs)
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py in data_generator(dataset, config, shuffle, augment, augmentation, random_rois, batch_size, detection_targets, no_augmentation_sources)
#    1707                     load_image_gt(dataset, config, image_id, augment=augment,
#    1708                                 augmentation=augmentation,
# -> 1709                                 use_mini_mask=config.USE_MINI_MASK)
#    1710
#    1711             # Skip images that have no instances. This can happen in cases
#
# D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\model.py in load_image_gt(dataset, config, image_id, augment, augmentation, use_mini_mask)
#    1217         min_scale=config.IMAGE_MIN_SCALE,
#    1218         max_dim=config.IMAGE_MAX_DIM,
# -> 1219         mode=config.IMAGE_RESIZE_MODE)
#    1220     mask = utils.resize_mask(mask, scale, padding, crop)
#    1221
#
# D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\utils.py in resize_image(image, min_dim, max_dim, min_scale, mode)
#     446     if scale != 1:
#     447         image = resize(image, (round(h * scale), round(w * scale)),
# --> 448                        preserve_range=True)
#     449
#     450     # Need padding or cropping?
#
# D:\Gproject\Codes\Mask_RCNN_1.14\mrcnn\utils.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     901             order=order, mode=mode, cval=cval, clip=clip,
#     902             preserve_range=preserve_range, anti_aliasing=anti_aliasing,
# --> 903             anti_aliasing_sigma=anti_aliasing_sigma)
#     904     else:
#     905         return skimage.transform.resize(
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\skimage\transform\_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     164         out = warp(image, tform, output_shape=output_shape, order=order,
#     165                    mode=mode, cval=cval, clip=clip,
# --> 166                    preserve_range=preserve_range)
#     167
#     168     else:  # n-dimensional interpolation
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\skimage\transform\_warps.py in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     905                                      mode=ndi_mode, order=order, cval=cval)
#     906
# --> 907     _clip_warp_output(image, warped, order, mode, cval, clip)
#     908
#     909     return warped
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\skimage\transform\_warps.py in _clip_warp_output(input_image, output_image, order, mode, cval, clip)
#     658             cval_mask = output_image == cval
#     659
# --> 660         np.clip(output_image, min_val, max_val, out=output_image)
#     661
#     662         if preserve_cval:
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\numpy\core\fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2082
#    2083     """
# -> 2084     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2085
#    2086
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\numpy\core\_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     130     else:
#     131         return _clip_dep_invoke_with_casting(
# --> 132             um.clip, a, min, max, out=out, casting=casting, **kwargs)
#     133
#     134 def _mean(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ~\Miniconda3\envs\mrcnn\lib\site-packages\numpy\core\_methods.py in _clip_dep_invoke_with_casting(ufunc, out, casting, *args, **kwargs)
#      83     # try to deal with broken casting rules
#      84     try:
# ---> 85         return ufunc(*args, out=out, **kwargs)
#      86     except _exceptions._UFuncOutputCastingError as e:
#      87         # Numpy 1.17.0, 2019-02-24
#
# KeyboardInterrupt:

# %% [markdown]
# ## Detection _ tunning
# ---

# %%
class InferenceConfig(CalcMassConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights

#normalized Data로 훈련 된 모델
#model_path = os.path.join(r'D:\Gproject\Codes\Mask_RCNN_1.14\logs\shapes20200521T0003_normalize', "mask_rcnn_shapes_0050.h5")

#normalized Data로 훈련 된 모델 X
#model_path = os.path.join(r'D:\Gproject\Codes\Mask_RCNN_1.14\logs\shapes20200527T0447', "mask_rcnn_shapes_0031.h5")
model_path = os.path.join(ROOT_DIR, ".h5")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  D:\Codes\Mask_RCNN\logs\shapes20200530T0601\mask_rcnn_shapes_0300.h5
# Re-starting from epoch 300

# %%
# Test on a random image
# well : 529
# 478
dataset =dataset_test
image_id = random.choice(dataset.image_ids)

print(image_id)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset.class_names, figsize=(8, 8))


results = model.detect([original_image], verbose=1)

r = results[0]

scores_thold = r["scores"]>0.95
cnt = 0
for i in scores_thold:
    if i ==True:
        cnt+=1

# if cnt ==0:
#     print("not detect")
# else:
visualize.display_instances(original_image, r['rois'][:cnt], r['masks'][...,:cnt], r['class_ids'][:cnt], 
                            dataset.class_names, r['scores'][:cnt], ax=get_ax())
print(r['scores'])
print(r['masks'].shape)
# Out:
# 61
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (15,)                 min:    0.00000  max: 3176.00000  float64
# gt_class_id              shape: (1,)                  min:    2.00000  max:    2.00000  int32
# gt_bbox                  shape: (1, 4)                min:  289.00000  max:  810.00000  int32
# gt_mask                  shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  bool
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 15)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.08847  max:    1.02591  float32
# [0.99995697 0.9758507  0.873425   0.7525113  0.71632147]
# (1024, 1024, 5)

# %%
scores_thold
# Out:
# array([ True,  True,  True,  True, False, False, False, False])

# %%
dataset_train.class_names
# Out:
# ['BG', 'Calc', 'Mass']

# %%
scores_thold = r["scores"]>0.95
cnt = 0
for i in scores_thold:
    if i ==True:
        cnt+=1
print(cnt)
# Out:
# 4

# %%
r["rois"][:cnt]
# Out:
# array([[870, 267, 980, 410],
#        [574, 367, 664, 479],
#        [427, 227, 517, 303],
#        [581, 394, 639, 446]])

# %%
r['masks'][...,:cnt].shape
# Out:
# (1024, 1024, 4)

# %%
r["class_ids"][:4]
# Out:
# array([2, 1, 2, 1])

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights

#model_path = os.path.join(r'E:\DataSet\logs\model_log', "mask_rcnn_shapes_0100.h5")
# model_path = os.path.join(r'E:\DataSet\logs\model_log', "mask_rcnn_shapes_0200.h5")
# model_path = os.path.join(r'E:\DataSet\logs\model_log', "mask_rcnn_shapes_0300.h5")

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
d_list = [dataset_train,dataset_val,dataset_test]

for i in d_list:
    image_ids = np.random.choice(i.image_ids, 100)
    APs = []
    precisions_list=[]
    recalls_list=[]
    overlaps_list=[]

    for image_id in image_ids:
        # Load image and ground truth data
        image, image_meta, gt_class_id, gt_bbox, gt_mask =\
            modellib.load_image_gt(i, inference_config,
                                   image_id, use_mini_mask=False)
        molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
        # Run object detection
        results = model.detect([image], verbose=0)
        r = results[0]
        # Compute AP
        AP, precisions, recalls, overlaps =\
            utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                             r["rois"], r["class_ids"], r["scores"], r['masks'])
        APs.append(AP)
        precisions_list.append(precisions)
        recalls_list.append(recalls)
        overlaps_list.append(overlaps)

    print(i,"mAP: ", np.mean(APs))
# Out:
# <__main__.CalcMassDataset_no_normalize object at 0x0000016B97931248> mAP:  0.7954841271496954
# <__main__.CalcMassDataset_no_normalize object at 0x0000016B89383808> mAP:  0.39184523819457917
# <__main__.CalcMassDataset_no_normalize object at 0x0000016BD8718FC8> mAP:  0.42667857142857146

# %%
# Get activations of a few sample layers
activations = model.run_graph([original_image], [
    ("input_image",        tf.identity(model.keras_model.get_layer("input_image").output)),
    ("res2c_out",          model.keras_model.get_layer("res2c_out").output),
    ("res3c_out",          model.keras_model.get_layer("res3c_out").output),
    ("rpn_bbox",           model.keras_model.get_layer("rpn_bbox").output),
    ("roi",                model.keras_model.get_layer("ROI").output),
])
# Out:
# input_image              shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10001  float32
# res2c_out                shape: (1, 256, 256, 256)    min:    0.00000  max:   16.44898  float32
# res3c_out                shape: (1, 128, 128, 512)    min:    0.00000  max:   18.64548  float32
# rpn_bbox                 shape: (1, 261888, 4)        min:  -22.30887  max:   42.95682  float32
# roi                      shape: (1, 1000, 4)          min:    0.00000  max:    1.00000  float32

# %%
from mrcnn.visualize import display_images

# Backbone feature map
display_images(np.transpose(activations["res2c_out"][0,:,:,:16], [2, 0, 1]), cols=8)
display_images(np.transpose(activations["res3c_out"][0,:,:,:16], [2, 0, 1]), cols=8)

# %% [markdown]
# ## Test
# ---

# %%
import json
with open(r"E:/DataSet/balloon/val/via_region_data.json", "r") as st_json:
    a = json.load(st_json)
a
# Out:
# {'24631331976_defa3bb61f_k.jpg668058': {'fileref': '',
#   'size': 668058,
#   'filename': '24631331976_defa3bb61f_k.jpg',
#   'base64_img_data': '',
#   'file_attributes': {},
#   'regions': {'0': {'shape_attributes': {'name': 'polygon',
#      'all_points_x': [916,
#       913,
#       905,
#       889,
#       868,
#       836,
#       809,
#       792,
#       789,
#       784,
#       777,
#       769,
#       767,
#       777,
#       786,
#       791,
#       769,
#       739,
#       714,
#       678,
#       645,
#       615,
#       595,
#       583,
#       580,
#       584,
#       595,
#       614,
#       645,
#       676,
#       716,
#       769,
#       815,
#       849,
#       875,
#       900,
#       916,
#       916],
#      'all_points_y': [515,
#       583,
#       616,
#       656,
#       696,
#       737,
#       753,
#       767,
#       777,
#       785,
#       785,
#       778,
#       768,
#       766,
#       760,
#       755,
#       755,
#       743,
#       728,
#       702,
#       670,
#       629,
#       588,
#       539,
#       500,
#       458,
#       425,
#       394,
#       360,
#       342,
#       329,
#       331,
#       347,
#       371,
#       398,
#       442,
#       504,
#       515]},
#     'region_attributes': {}}}},
#  '16335852991_f55de7958d_k.jpg1767935': {'fileref': '',
#   'size': 1767935,
#   'filename': '16335852991_f55de7958d_k.jpg',
#   'base64_img_data': '',
#   'file_attributes': {},
#   'regions': {'0': {'shape_attributes': {'name': 'polygon',
#      'all_points_x': [588,
#       617,
#       649,
#       673,
#       692,
#       708,
#       722,
#       730,
#       737,
#       718,
#       706,
#       699,
#       697,
#       676,
#       650,
#       613,
#       580,
#       552,
#       534,
#       520,
#       513,
#       513,
#       521,
#       526,
#       541,
#       560,
#       588],
#      'all_points_y': [173,
#       168,
#       172,
#       182,
#       197,
#       216,
#       237,
#       260,
#       283,
#       312,
#       341,
#       367,
#       390,
#       369,
#       349,
#       337,
#       337,
#       347,
#       361,
#       332,
#       296,
#       266,
#       243,
#       225,
#       205,
#       187,
#       173]},
#     'region_attributes': {}},
#    '1': {'shape_attributes': {'name': 'polygon',
#      'all_points_x': [845,
#       861,
#       880,
#       892,
#       902,
#       910,
#       889,
#       869,
#       844,
#       813,
#       785,
#       762,
#       745,
#       739,
#       731,
#       746,
#       767,
#       790,
#       821,
#       845],
#      'all_points_y': [219,
#       229,
#       242,
#       260,
#       275,
#       299,
#       277,
#       263,
#       254,
#       250,
#       255,
#       265,
#       279,
#       283,
#       258,
#       241,
#       225,
#       216,
#       213,
#       219]},
#     'region_attributes': {}},
#    '2': {'shape_attributes': {'name': 'polygon',
#      'all_points_x':
IMG_PATH = r'E:\DataSet\balloon\train\34020010494_e5cb88e1c4_k.jpg'
imgs = glob.glob(IMG_PATH)
x = [ 1020, 1000, 994, 1003, 1023, 1050, 1089, 1134, 1190, 1265, 1321, 1361, 1403, 1428, 1442, 1445, 1441, 1427, 1400, 1361, 1316, 1269, 1228, 1198, 1207, 1210, 1190, 1177, 1172, 1174, 1170, 1153, 1127, 1104, 1061, 1032, 1020 ]
y = [ 963, 899, 841, 787, 738, 700, 663, 638, 621, 619, 643, 672, 720, 765, 800, 860, 896, 942, 990, 1035, 1079, 1112, 1129, 1134, 1144, 1153, 1166, 1166, 1150, 1136, 1129, 1122, 1112, 1084, 1037, 989, 963 ]

# %%
img = plt.imread(imgs[0])

for i in range(len(x)):
    cv.circle(img,(x[i],y[i]),20,(255,0,0),-1)

plt.imshow(img)

# %%
IMG_PATH = r'E:\DataSet\balloon\train\25899693952_7c8b8b9edc_k.jpg'
imgs = glob.glob(IMG_PATH)
x = [ 586, 510, 441, 389, 331, 268, 196, 158, 135, 156, 210, 307, 403, 437, 443, 425, 448, 481, 506, 513, 503, 511, 502, 583, 669, 755, 800, 811, 803, 784, 755, 717, 668, 620, 586 ]
y = [ 133, 116, 115, 126, 149, 185, 261, 339, 438, 560, 664, 784, 868, 893, 929, 964, 964, 961, 965, 958, 936, 910, 896, 836, 752, 636, 538, 454, 392, 329, 270, 220, 175, 149, 133 ]

# %%
img = plt.imread(imgs[0])

for i in range(len(x)):
    cv.circle(img,(x[i],y[i]),20,(255,0,0),-1)

plt.imshow(img)

# %%
IMG_PATH = r'E:\DataSet\balloon\train\605521662_a470fef77f_b.jpg'
imgs = glob.glob(IMG_PATH)

x= [ 400, 424, 450, 444, 456, 470, 488, 485, 473, 449, 423, 391, 361, 342, 341, 356, 373, 400 ]
y= [ 368, 368, 377, 391, 384, 397, 435, 469, 497, 519, 528, 522, 501, 466, 424, 397, 380, 368 ]

# %%
img = plt.imread(imgs[0])

for i in range(len(x)):
    cv.circle(img,(x[i],y[i]),20,(255,0,0),-1)

plt.imshow(img)

# %%
IMG_PATH = r'E:\DataSet\balloon\train\351678851_e2aeebdafd_b.jpg'
imgs = glob.glob(IMG_PATH)

x1 = [ 67, 105, 137, 163, 169, 171, 161, 137, 87, 44, 2, 2, 32, 57, 67 ]
y1 = [ 15, 42, 72, 117, 144, 204, 247, 288, 274, 278, 295, 0, 0, 5, 15 ]
x11 = [ 601, 584, 562, 530, 489, 450, 415, 376, 340, 311, 288, 273, 265, 266, 279, 303, 330, 361, 399, 438, 478, 516, 548, 581, 595, 607, 607, 601 ]
y11 = [ 253, 297, 325, 357, 383, 400, 407, 410, 401, 370, 330, 290, 247, 210, 167, 124, 96, 76, 60, 55, 55, 68, 86, 118, 148, 187, 226, 253 ]

# %%
img = plt.imread(imgs[0])

for i in range(len(x1)):
    cv.circle(img,(x1[i],y1[i]),20,(255,0,0),-1)
    
for i in range(len(x11)):
    cv.circle(img,(x11[i],y11[i]),20,(255,0,0),-1)

plt.imshow(img)
